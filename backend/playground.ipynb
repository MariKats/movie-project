# %%
from app.core.config import settings, BASE_DIR
print(f"Database URL: {settings.DATABASE_URL}")
print(f"Secret Key: {settings.OMDB_API_KEY}")
print(f"Base Directory: {BASE_DIR}")
# Out:
# Database URL: postgresql://user:password@localhost:5432/mydatabase
# Secret Key: cbde2058
# Base Directory: /Users/mariannaki/Development/movie-project/backend

# %%
import requests

title = "Natural Born Killers"

r = requests.post(
    url=f"http://127.0.0.1:8000/movies/?title={title}",
    headers={"Content-type": "application/json"},
)
print(r)
# Out:
# <Response [200]>

# %%
from app.services.constants import RequiredMovieFields

print([f.value for f in RequiredMovieFields])
print(RequiredMovieFields._member_names_)
# Out:
# ['Title', 'Plot', 'Actors', 'Year', 'Genre', 'Director']
# ['Title', 'Plot', 'Actors', 'Year', 'Genre', 'Director']
